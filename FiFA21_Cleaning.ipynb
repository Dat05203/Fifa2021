# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import os
import re

pd.options.display.max_columns = None
pd.options.display.max_rows = 200

# %% [markdown]
# ### Import Data

# %%
data_csv = "/content/fifa21_raw_data.csv"
data = pd.read_csv(data_csv)

# %% [markdown]
# # Cleaning & Processing

# %%
data.head()
# Out:
#                 Name Nationality Positions  Age                 Team  \
# 0           L. Messi   Argentina  RW ST CF   33         FC Barcelona
# 1  Cristiano Ronaldo    Portugal     ST LW   35             Juventus
# 2           J. Oblak    Slovenia        GK   27      Atlético Madrid
# 3       K. De Bruyne     Belgium    CAM CM   29      Manchester City
# 4          Neymar Jr      Brazil    LW CAM   28  Paris Saint-Germain
#
#       Contract  Overal  Potential  Height  Weight   foot  Best Overall Blance  \
# 0  2004 - 2021      93         93     170      72   Left            93     RW
# 1  2018 - 2022      92         92     188      83  Right            92     ST
# 2  2014 - 2023      91         93     188      87  Right            91     GK
# 3  2015 - 2023      91         91     180      70  Right            91    CAM
# 4  2017 - 2022      91         91     175      68  Right            91     LW
#
#    Growth       Value      Wage  Attacking  Crossing  Finishing  \
# ...

# %%
data.describe(include=object)
# Out:
#                                                 photoUrl    LongName  \
# count                                              18979       18979
# unique                                             18978       18851
# top     https://cdn.sofifa.com/players/251/698/21_60.png  Liam Kelly
# freq                                                   2           3
#
#                                                 playerUrl Nationality  \
# count                                               18979       18979
# unique                                              18978         164
# top     http://sofifa.com/player/251698/kevin-berlaso/...     England
# freq                                                    2        1704
#
#        Positions          Name     Team & Contract Height  Weight   foot  \
# count      18979         18979               18979  18979   18979  18979
# unique       640         17919                9023     21      56      2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   photoUrl          18979 non-null  object
#  1   LongName          18979 non-null  object
#  2   playerUrl         18979 non-null  object
#  3   Nationality       18979 non-null  object
#  4   Positions         18979 non-null  object
#  5   Name              18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Team & Contract   18979 non-null  object
#  10  ID                18979 non-null  int64
#  11  Height            18979 non-null  object
#  12  Weight            18979 non-null  object
#  13  foot              18979 non-null  object
#  14  BOV               18979 non-null  int64
#  15  BP                18979 non-null  object
# ...

# %%
data.shape
# Out:
# (18979, 77)

# %% [markdown]
# ### Convert Datatime for Joined column

# %%
data.Joined.value_counts()
# Out:
# Jul 1, 2019     1344
# Jul 1, 2018      865
# Jan 1, 2019      682
# Jul 1, 2017      520
# Jul 1, 2020      435
#                 ...
# May 17, 2018       1
# Feb 25, 2015       1
# Jun 1, 2005        1
# Sep 10, 2016       1
# Feb 28, 2015       1
# Name: Joined, Length: 1869, dtype: int64

# %%
from numpy.core.fromnumeric import size
month_dict = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4, 'May':5, 'Jun':6, 'Jul':7, 'Aug':8, 'Sep':9, 'Oct':10, 'Nov':11, 'Dec':12}

def convertDay(date : str):
    month, day, year = re.findall(r'\w+', date)
    month = month_dict.get(month)
    if day != None and len(day) < 2 : day = f"0{day}"
    if month != None and month/10 < 1: month = f"0{month}"
    return f"{year}-{month}-{day}"

data.Joined = data.Joined.apply(convertDay)

# %%
data.Joined.value_counts()
# Out:
# 2019-07-01    1344
# 2018-07-01     865
# 2019-01-01     682
# 2017-07-01     520
# 2020-07-01     435
#               ...
# 2018-05-17       1
# 2015-02-25       1
# 2005-06-01       1
# 2016-09-10       1
# 2015-02-28       1
# Name: Joined, Length: 1869, dtype: int64

# %%
# Convert Joined to Datatime
data['Joined'] = pd.to_datetime(data['Joined'], format='%Y-%m-%d')

# %%
print(data['Joined'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# ### Convert Height from feet-inch to centimeter

# %%
data['Height'].value_counts()
# Out:
# 6'0"     2859
# 5'10"    2654
# 5'9"     2304
# 5'11"    2188
# 6'2"     2108
# 6'1"     2001
# 5'8"     1069
# 6'3"     1049
# 5'7"      953
# 6'4"      797
# 5'6"      332
# 6'5"      280
# 5'5"      188
# 6'6"      116
# 5'4"       33
# 6'7"       20
# 5'3"       15
# 6'8"        6
# 5'2"        4
# 5'1"        2
# 6'9"        1
# Name: Height, dtype: int64

# %%
def convertHeight(height: str):
  if ("\'") not in height: return height
  feet, inch = pd.to_numeric(re.findall(r'\d+', string = height))
  return round(feet*30.48 + inch*2.54)
data['Height'] = data['Height'].apply(convertHeight)

# %%
data['Height']
# Out:
# 0        170
# 1        188
# 2        188
# 3        180
# 4        175
#         ...
# 18974    178
# 18975    170
# 18976    178
# 18977    175
# 18978    175
# Name: Height, Length: 18979, dtype: int64

# %% [markdown]
# ### Converting Weight from Pound to Kg

# %%
data['Weight'].value_counts()
# Out:
# 154lbs    1496
# 165lbs    1458
# 176lbs    1109
# 159lbs    1024
# 172lbs     995
# 163lbs     957
# 161lbs     956
# 170lbs     893
# 168lbs     880
# 150lbs     795
# 174lbs     684
# 157lbs     648
# 181lbs     622
# 152lbs     566
# 143lbs     535
# 179lbs     523
# 183lbs     515
# 148lbs     508
# 185lbs     444
# 187lbs     423
# 146lbs     401
# 141lbs     341
# 190lbs     285
# 194lbs     266
# 139lbs     239
# 192lbs     224
# 137lbs     181
# 198lbs     156
# 132lbs     153
# 196lbs     128
# 134lbs      96
# 201lbs      87
# 203lbs      68
# 205lbs      52
# 128lbs      44
# 130lbs      41
# 207lbs      34
# 209lbs      30
# 126lbs      19
# 121lbs      17
# 212lbs      15
# 216lbs      13
# 123lbs      12
# 214lbs       9
# 220lbs       8
# 119lbs       5
# 227lbs       4
# 225lbs       4
# 223lbs       4
# 218lbs       3
# 229lbs       3
# 115lbs       2
# 236lbs       1
# 243lbs       1
# 117lbs       1
# 110lbs       1
# Name: Weight, dtype: int64

# %%
def convertWeight(weight: str):
  if 'lbs' not in weight: return weight
  lbs = pd.to_numeric(re.findall(pattern = '\d+', string = weight))[0]
  return round(lbs*0.453592)

data.Weight = data.Weight.apply(convertWeight)

# %%
data.Weight
# Out:
# 0        72
# 1        83
# 2        87
# 3        70
# 4        68
#          ..
# 18974    70
# 18975    58
# 18976    66
# 18977    65
# 18978    68
# Name: Weight, Length: 18979, dtype: int64

# %%
data.head()
# Out:
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                        LongName  \
# 0                  Lionel Messi
# 1  C. Ronaldo dos Santos Aveiro
# 2                     Jan Oblak
# 3               Kevin De Bruyne
# 4    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality Positions  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  RW ST CF
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal     ST LW
# 2  http://sofifa.com/player/200389/jan-oblak/210005/    Slovenia        GK
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium    CAM CM
# ...

# %%
def split_team_contract(col=None):
  col = col.str.replace(r'^[\n]{4}','')     # xóa 4 kí tự '\n' ở đầu
  col = col.str.replace(r'[\n]{2}','')      # xóa 2 kí tự '\n' ở cuối
  data[['Team','Contract']] = col.str.split('\n',1,expand=True)     # chia chuỗi ở vị trí kí tự '\n'
  return col
data['Team & Contract'] = split_team_contract(data['Team & Contract'])

#drop column Team & Contract
data = data.drop(columns=['Team & Contract'])
# Out:
# <ipython-input-69-aec41679565b>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   col = col.str.replace(r'^[\n]{4}','')     # xóa 4 kí tự '\n' ở đầu
# <ipython-input-69-aec41679565b>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   col = col.str.replace(r'[\n]{2}','')      # xóa 2 kí tự '\n' ở cuối
# <ipython-input-69-aec41679565b>:4: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   data[['Team','Contract']] = col.str.split('\n',1,expand=True)     # chia chuỗi ở vị trí kí tự '\n'

# %%
# Replace '~' to '-'
data['Contract'] = data['Contract'].str.replace('~', '-')

# %% [markdown]
# ### Process Value, Wage and Rease Clause columns

# %%
def clean_column(col):
  col = col.lstrip('€')
  end_char = col[-1]  #get the end character
  if end_char == 'M':
    return float(col[:-1]) * 1e6
  elif end_char == 'K':
    return float(col[:-1]) * 1e3
  else:
    return float(col)

# %%
# excu clean_column function

data['Value'] = data['Value'].apply(clean_column)

data['Wage'] = data['Wage'].apply(clean_column)

data['Release Clause'] = data['Release Clause'].apply(clean_column)

# %% [markdown]
# ### Process W/F, SM and IR columns

# %%
# Remove '★'
def remove_star(col):
  col = col.rstrip('★')
  return int(col)

# %%
# exc remove_star function
data['W/F'] = data['W/F'].apply(remove_star)

data['SM'] = data['SM'].apply(remove_star)

data['IR'] = data['IR'].apply(remove_star)

# %% [markdown]
# ### Process Hits column

# %%
def convert_value(col):
  if isinstance(col, str):
    col = col.lstrip('\n')
    if col.endswith('K'):
      return float(col[:-1]) * 1e3
    else:
      return float(col)
  else:
    return float(col)

# %%
# exc convert_value function

data['Hits'] = data['Hits'].apply(convert_value)

# %% [markdown]
# ### Process Loan Date End

# %%
data['Loan Date End']= pd.to_datetime(data['Loan Date End'])

# %% [markdown]
# ### Reorder the columns and drop (photoUrl, playerUrl, ID, Joined, Loan Date End) columns

# %%
data = data[['Name','Nationality','Positions','Age','Team','Contract','↓OVA', 'POT','Height','Weight','foot','BOV','BP','Growth','Value','Wage','Attacking','Crossing','Finishing','Heading Accuracy','Short Passing',
             'Volleys','Skill','Dribbling', 'Curve','FK Accuracy','Long Passing', 'Ball Control','Movement','Acceleration','Sprint Speed','Agility','Reactions','Balance','Power','Shot Power','Jumping',	'Stamina',	'Strength',
             'Long Shots','Mentality',	'Aggression','Interceptions',	'Positioning',	'Vision','Penalties',	'Composure',	'Defending',	'Marking','Standing Tackle','Sliding Tackle','Goalkeeping','GK Diving',	'GK Handling',
             'GK Kicking',	'GK Positioning',	'GK Reflexes',	'Total Stats',	'Base Stats',	'W/F',	'SM',	'A/W',	'D/W',	'IR',	'PAC',	'SHO',	'PAS',	'DRI',	'DEF',	'PHY',	'Hits']]

# %% [markdown]
# ### Rename some columns

# %%
data.rename(columns = {'↓OVA':'Overal', 'POT':'Potential', 'BOV':'Best Overall', 'BP':'Blance','IR':'Reputation'}, inplace = True)
# Out:
# <ipython-input-81-952cb8a99257>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns = {'OVA':'Overal', 'POT':'Potential', 'BOV':'Best Overall', 'BP':'Blance','IR':'Reputation'}, inplace = True)

# %% [markdown]
# ### Export to csv file

# %%
data.to_csv('fifa21_clean_data.csv')
